# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
from keras.models import load_model

# %%
model = load_model('./model/_2/fucking_model3.h5')
# Out:
# WARNING:tensorflow:From D:\Programfile\Anaconda\envs\bam\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\Programfile\Anaconda\envs\bam\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From D:\Programfile\Anaconda\envs\bam\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(featurewise_center=False, samplewise_center=False, featurewise_std_normalization=False, samplewise_std_normalization=False, zca_whitening=False, zca_epsilon=1e-06, rotation_range=0, width_shift_range=0.0, height_shift_range=0.0, brightness_range=None, shear_range=0.0, zoom_range=0.0, channel_shift_range=0.0, fill_mode='nearest', cval=0.0, horizontal_flip=False, vertical_flip=False, rescale=None, preprocessing_function=None, data_format=None, validation_split=0.0)
test_generator = datagen.flow_from_directory(
        'drawcontour/test',
        target_size=(100, 100),shuffle=True,
        batch_size=32,color_mode='rgb',
        class_mode='categorical')
# Out:
# Found 1800 images belonging to 3 classes.

# %%
print(test_generator.class_indices)
# Out:
# {'hammer': 0, 'paper': 1, 'scissor': 2}

# %%
output_dict = {0:'hammer', 1: 'paper', 2:'scissor'}

# %%
from keras.optimizers import Adam
adam = Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=adam,metrics=['accuracy'])

# %%
scores3 = model.evaluate_generator(test_generator,60)
print(scores3)
# Out:
# [5.372698498174611, 0.6666666666666666]

# %%
import cv2 as cv
import os

# %%
path = './drawcontour/test/hammer/'
image_list = os.listdir(path)

# %%
def predict(model,x):
    x = np.reshape(x,(-1,100,100,3))
    x = x/255
    y = model.predict(x)
    y = np.argmax(y,axis=1)
    return y

# %%
for i in range(len(image_list)):
    img = cv.imread(path+image_list[i])
    y = predict(model,img)
    print(output_dict[y[0]])
# Out:
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# paper
# scissor
# paper
# scissor
# paper
# scissor
# scissor
# paper
# scissor
# scissor
# scissor
# paper
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# paper
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# paper
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# paper
# scissor
# paper
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# paper
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# paper
# paper
# paper
# scissor
# scissor
# scissor
# paper
# paper
# hammer
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# paper
# scissor
# paper
# scissor
# scissor
# scissor
# scissor
# paper
# ...

# %%
path = './drawcontour/test/paper/'
image_list = os.listdir(path)
for i in range(len(image_list)):
    img = cv.imread(path+image_list[i])
    y = predict(model,img)
    print(output_dict[y[0]])
# Out:
# paper
# paper
# paper
# paper
# paper
# scissor
# paper
# paper
# paper
# paper
# paper
# scissor
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# scissor
# paper
# paper
# paper
# scissor
# paper
# scissor
# scissor
# paper
# paper
# paper
# scissor
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# scissor
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# scissor
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# scissor
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# scissor
# paper
# paper
# paper
# paper
# scissor
# scissor
# paper
# paper
# paper
# paper
# scissor
# paper
# paper
# paper
# scissor
# scissor
# paper
# paper
# paper
# scissor
# paper
# paper
# paper
# scissor
# paper
# paper
# scissor
# paper
# paper
# scissor
# scissor
# paper
# paper
# paper
# paper
# paper
# paper
# ...

# %%
path = './drawcontour/test/scissor/'
image_list = os.listdir(path)
for i in range(len(image_list)):
    img = cv.imread(path+image_list[i])
    y = predict(model,img)
    print(output_dict[y[0]])
# Out:
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# paper
# scissor
# paper
# scissor
# paper
# scissor
# scissor
# paper
# scissor
# scissor
# scissor
# paper
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# paper
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# paper
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# paper
# scissor
# paper
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# paper
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# paper
# paper
# paper
# scissor
# scissor
# scissor
# paper
# paper
# hammer
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# scissor
# paper
# scissor
# paper
# scissor
# scissor
# scissor
# scissor
# paper
# ...
